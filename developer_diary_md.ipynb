# %% [markdown]
# <a href="https://colab.research.google.com/github/raeescaunhye27-ops/smart-finance-assistant/blob/main/developer_diary_md.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Developer’s Diary – Smart Finance Assistant
#
# Student Name: **Caunhye Mohammad Ar-Raees **
# Student ID: **23588204**
#
# This diary documents my AI collaboration, development progress, reflections, and improvements made during the Smart Finance Assistant project.

# %% [markdown]
# ## Entry 1 — Understanding the Finance Problem
#
# ### Artifact
# ![image.png](data:image/png;base64,...)
#
# ### Context
# At the beginning of the project, I needed to identify a realistic finance problem that could be solved using data analysis and AI. I wanted a project idea that was practical, useful, and suitable for analysing CSV transaction files.
#
# ### My Prompt
# "Help me brainstorm finance problems that could be solved using CSV transaction analysis."
#
# ### AI Response Summary
# AI suggested ideas related to budgeting, spending analysis, savings tracking, and financial recommendations.
#
# ### My Critique/Improvement
# I selected the budgeting and spending analysis idea because it was realistic and matched the assignment requirements. I simplified the project scope to focus on CSV analysis and budgeting advice.
#
# ### Result
# I created a clear business problem statement explaining how the assistant helps users understand spending habits and improve budgeting decisions.
#
# ### Reflection
# I learned that defining the business problem first makes it easier to design the program features and structure. AI helped generate ideas quickly, but I still needed to choose the most suitable and realistic solution.

# %% [markdown]
# ## Entry 2 — Creating Sample Transaction Data
#
# ### Artifact
# Screenshot of AI-generated transaction dataset.
#
# ### Context
# I wanted realistic financial transaction data for testing the Smart Finance Assistant.
#
# ### My Prompt
# "Create realistic Australian transaction data with categories such as groceries, transport, entertainment, coffee, and refunds."
#
# ### AI Response Summary
# AI generated transaction examples using realistic Australian businesses and spending categories.
#
# ### My Critique/Improvement
# I modified some transaction descriptions and added refund examples to improve testing coverage.
#
# ### Result
# I created a sample pandas DataFrame with realistic transaction data for development and testing.
#
# ### Reflection
# I learned that realistic test data is important because it helps simulate real business scenarios. AI helped save time generating data while still allowing me to customise and improve the final dataset.

# %% [markdown]
# ## Entry 3 — Debugging the hands-on-ai Connection
#
# ### Artifact
# Screenshot of ChatGPT explaining the chat.say() error.
#
# ### Context
# I received an error because the chat.say() function did not exist in the hands-on-ai package.
#
# ### My Prompt
# "I get an error saying the say function does not exist. Can you help fix the code?"
#
# ### AI Response Summary
# AI explained that chat.say() was outdated and suggested using get_response() from hands_on_ai.chat instead.
#
# ### My Critique/Improvement
# I tested the updated code and confirmed that the connection worked successfully.
#
# ### Result
# I corrected the connection test using:
#
# ```python
# from hands_on_ai.chat import get_response

# %% [markdown]
# Reflection
#
# I learned that documentation is important when working with AI libraries and APIs. AI tools helped identify the problem quickly and explain the correct implementation.

# %% [markdown]
# # ✅ ENTRY 4 — WRITING PSEUDOCODE
#
# ```markdown
# ## Entry 4 — Writing Pseudocode
#
# ### Artifact
# Screenshot of AI reviewing finance assistant pseudocode.
#
# ### Context
# I wanted to organise the program logic before starting Python implementation.
#
# ### My Prompt
# "Review my pseudocode for analyzing spending data and suggest improvements or edge cases."
#
# ### AI Response Summary
# AI suggested adding refund handling, data validation, and error checking.
#
# ### My Critique/Improvement
# I added steps for handling missing values, negative amounts, and invalid CSV files.
#
# ### Result
# I created structured pseudocode covering data loading, cleaning, analysis, recommendations, chatbot functions, and Gradio integration.
#
# ### Reflection
# I learned that planning program logic before coding helps reduce mistakes and improves software structure. AI also helped me think about real-world business data problems.

# %% [markdown]
# ## Entry 5 — Converting Pseudocode into Python
#
# ### Artifact
# Screenshot of Python functions generated with AI assistance.
#
# ### Context
# I wanted to convert the finance assistant pseudocode into working Python code.
#
# ### My Prompt
# "Create Python functions for transaction cleaning, spending analysis, and financial recommendations."
#
# ### AI Response Summary
# AI generated pandas functions for loading CSV files, cleaning data, grouping spending categories, and generating budgeting advice.
#
# ### My Critique/Improvement
# I improved the readability of the code by adding comments, business-focused variable names, and additional validation steps.
#
# ### Result
# I created working Python functions that analyse transaction data and generate budgeting insights.
#
# ### Reflection
# I learned how Python and pandas can be used to process business data. AI accelerated development, but I still needed to test, review, and understand the code before using it.

# %% [markdown]
# 📸 WHAT SCREENSHOTS YOU SHOULD ADD
#
# Put screenshots in:
#
# AI-CONVERSATIONS/
#
# Examples:
#
# week8-finance-problem.png
# week8-sample-data.png
# week9-debugging-error.png
# week9-pseudocode-help.png
# week10-python-functions.png

# %% [markdown]
# IMPORTANT
#
# The diary is worth marks because of:
#
# reflection
# learning
# improvements
# AI collaboration evidence
#
# According to the assignment guide:
#
# You should show:
#
# what AI helped with
# what problems happened
# how you improved the AI response
# what you learned
#
# That is what tutors look for.
