# %% [markdown]
# <a href="https://colab.research.google.com/github/raeescaunhye27-ops/smart-finance-assistant/blob/main/ai_conversations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# AI Conversation – Smart Finance Assistant
# User:
#
# Hello AI assistant, I need help managing my money.
#
# AI Assistant:
#
# Hello! I’d be happy to help you improve your finances. What would you like help with today?
#
# User:
#
# I always run out of money before the end of the month.
#
# AI Assistant:
#
# That usually happens when spending is not tracked properly. I recommend creating a monthly budget and separating your expenses into:
#
# Needs
# Wants
# Savings
#
# This makes it easier to control unnecessary spending.
#
# User:
#
# I spend too much on online shopping.
#
# AI Assistant:
#
# A useful strategy is to set a weekly spending limit and avoid impulse purchases. Try waiting 24 hours before buying non-essential items online.
#
# User:
#
# How much money should I save every month?
#
# AI Assistant:
#
# A common recommendation is saving at least 20% of your income if possible. However, even small amounts saved consistently can make a big difference over time.
#
# User:
#
# I’m a university student with limited income.
#
# AI Assistant:
#
# Students can still build strong financial habits by:
#
# Tracking daily expenses
# Avoiding unnecessary subscriptions
# Cooking at home more often
# Using student discounts
#
# Small savings add up over time.
#
# User:
#
# Can you suggest a budgeting method?
#
# AI Assistant:
#
# Yes! The 50/30/20 budgeting rule is very popular:
#
# 50% for needs
# 30% for wants
# 20% for savings
#
# It’s simple and beginner-friendly.
#
# User:
#
# What is an emergency fund?
#
# AI Assistant:
#
# An emergency fund is money saved for unexpected situations such as medical expenses, car repairs, or job loss. Financial experts recommend saving enough for 3–6 months of expenses.
#
# User:
#
# Should I invest my money?
#
# AI Assistant:
#
# Investing can help grow your money, but it’s important to:
#
# Build savings first
# Understand investment risks
# Start with low-risk options
#
# Always research before investing.
#
# User:
#
# Thank you for the advice.
#
# AI Assistant:
#
# You’re welcome!  Remember, smart financial decisions today can help create a secure future. Keep tracking your spending and saving consistently.

# %% [markdown]
# 📌 Context / Goal
#
# I wanted to improve my Python function by adding proper comments and a docstring because my lecturer required professional documentation standards for the Smart Finance Assistant project.
#
# 💬 Full AI Conversation Evidence
# 👨‍💻 Student Prompt
#
# Yes, please create the function to validate user input in python for an integer.
#
# 🤖 AI Response
# def get_valid_integer(prompt="Enter an integer: "):
#     while True:
#         user_input = input(prompt)
#         try:
#             value = int(user_input)
#             return value
#         except ValueError:
#             print("Invalid input. Please enter a valid integer.")
# 👨‍💻 Student Follow-Up
#
# Hey I have an annoying lecturer, they want the code to be commented, and he mention a weird thing called docstring or something. Can you fix this function?
#
# 🤖 AI Response
# from typing import Optional
#
# def get_valid_integer(
#     prompt: str = "Enter an integer: ",
#     *,
#     min_value: Optional[int] = None,
#     max_value: Optional[int] = None,
#     retries: Optional[int] = None
# ) -> int:
#     """
#     Prompt the user until they enter a valid integer and return it.
#
#     This function repeatedly prompts via input() and returns the parsed
#     integer once valid.
#     """
#
#     if min_value is not None and max_value is not None and min_value > max_value:
#         raise ValueError("min_value cannot be greater than max_value.")
#
#     attempts = 0
#
#     while True:
#         raw = input(prompt)
#
#         try:
#             value = int(raw)
#         except ValueError:
#             print("Invalid input.")
#             attempts += 1
#         else:
#             return value
# 👨‍💻 Student Reflection
#
# Wow... I am a beginner, that looks confusing. I thought you just add some comments or something. What does the -> int mean etc... we haven’t learned that.
#
# 🤖 AI Simplified Response
# def get_valid_integer(prompt="Enter an integer: "):
#     """
#     Ask the user to enter an integer and keep asking until they do.
#
#     Args:
#         prompt (str): The message shown to the user.
#
#     Returns:
#         int: The valid integer entered by the user.
#     """
#
#     while True:
#         # Ask the user for input
#         user_input = input(prompt)
#
#         try:
#             # Try converting the input into an integer
#             value = int(user_input)
#
#             # Return the valid integer
#             return value
#
#         except ValueError:
#             # If conversion fails, show an error message
#             print("Invalid input. Please enter a whole number.")
# 👨‍💻 Student Question
#
# Are there different docstring styles?
#
# 🤖 AI Explanation
#
# The AI explained several docstring styles:
#
# ✅ Simple / PEP257 Style
# """
# Add two numbers and return the result.
# """
# ✅ Google Style
# """
# Args:
#     a (int): First number.
# """
# ✅ NumPy Style
# """
# Parameters
# ----------
# a : int
# """
# ✅ reStructuredText (Sphinx)
# """
# :param a: First number
# :type a: int
# """
# 📘 What I Learned
# I learned what a docstring is and why lecturers require it.
# I learned how comments improve code readability.
# I learned that there are different documentation styles used in professional programming.
# I learned how AI can simplify complicated code explanations for beginners.
# 🧠 Reflection
#
# At first, the AI generated code that was too advanced for my skill level. It included concepts like type hints and optional parameters that we had not learned in class yet. I asked the AI to simplify the explanation, and it produced a much more beginner-friendly version with comments and a simple docstring. This helped me understand how to properly document functions in Python.
